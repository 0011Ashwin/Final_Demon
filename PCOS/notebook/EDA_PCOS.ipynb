# %% [markdown]
# # PCOS: Polycystic Ovary Syndrome #

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r'c:/Users/ashwi/OneDrive/Desktop/Final_Demon/PCOS/notebook/data/data.csv')

# %%
df
# Out:
#               Age  Weight_kg  Height_ft Marital_Status PCOS  \
# 0           20-25       66.0     157.48      Unmarried   No
# 1    Less than 20       56.0     165.10      Unmarried   No
# 2    Less than 20       89.0     167.64      Unmarried   No
# 3           20-25       55.0     160.02      Unmarried   No
# 4    Less than 20       55.0     160.02      Unmarried   No
# ..            ...        ...        ...            ...  ...
# 168  Less than 20       49.0     157.48      Unmarried   No
# 169         20-25       90.0     170.18      Unmarried  Yes
# 170         20-25       49.0     162.56      Unmarried  Yes
# 171  Less than 20       52.0     124.46      Unmarried   No
# 172         20-25       68.0     162.56      Unmarried   No
#
#     Family_History_PCOS Menstrual_Irregularity Hormonal_Imbalance  \
# 0                    No                    Yes                 No
# 1                    No                     No                 No
# ...

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 13 numerical features : ['Weight_kg', 'Height_ft', 'Diet_Bread_Cereals', 'Diet_Milk_Products', 'Diet_Fruits', 'Diet_Vegetables', 'Diet_Starchy_Vegetables', 'Diet_NonStarchy_Vegetables', 'Diet_Fats', 'Diet_Sweets', 'Diet_Fried_Food', 'Diet_Tea_Coffee', 'Diet_Multivitamin']
#
# We have 23 categorical features : ['Age', 'Marital_Status', 'PCOS', 'Family_History_PCOS', 'Menstrual_Irregularity', 'Hormonal_Imbalance', 'Hyperandrogenism', 'Hirsutism', 'Mental_Health', 'Conception_Difficulty', 'Insulin_Resistance', 'Diabetes', 'Childhood_Trauma', 'Cardiovascular_Disease', 'Vegetarian', 'Exercise_Frequency', 'Exercise_Type', 'Exercise_Duration', 'Sleep_Hours', 'Stress_Level', 'Smoking', 'Exercise_Benefit', 'PCOS_Medication']

# %% [markdown]
# ## Set of feature of dataset ##
# ### Categorical features ###

# %%
print("Categorical in 'Age' variable: ", end=" ")
print(df['Age'].unique())

# print("categorical in 'Marital_Status' variable: ",end=" ")
# print(df['Marital_Status'].unique())

print("categorical in 'PCOS' variable: ", end=" ")
print(df['PCOS'].unique())

print("categorical in 'Hormonal_Imbalance' variable: ",end=" ")
print(df['Hormonal_Imbalance'].unique())

print("categorical in 'Diabetes' variable: ", end=" ")
print(df['Diabetes'].unique())
# Out:
# Categorical in 'Age' variable:  ['20-25' 'Less than 20' '45 and above' '30-35' '35-44' '25-30']
# categorical in 'PCOS' variable:  ['No' 'Yes' 'No, Yes, not diagnosed by a doctor']
# categorical in 'Hormonal_Imbalance' variable:  ['No' 'Yes' 'No, Yes, not diagnosed by a doctor'
#  'Yes, not diagnosed by a doctor, Yes, diagnosed by a doctor']
# categorical in 'Diabetes' variable:  ['No' 'Yes' 'No, Yes, not diagnosed by a doctor']

# %% [markdown]
# ### Numerical features:

# %%
# : ['Weight_kg', 'Height_ft'
#    'Diet_Sweets', 'Diet_Fried_Food', 'Diet_Tea_Coffee'
print("Numerical in 'Weight_kg' variable: ", end=" ")
print(df['Weight_kg'].unique())

print("Numerical in 'Height_ft' variable: ", end=" ")
print(df['Height_ft'].unique())

print("Numerical in 'Diet_Sweets' variable: ", end=" ")
print(df['Diet_Sweets'].unique())

print("Numerical in 'Diet_Fried_Food' variable: ", end=" ")
print(df['Diet_Fried_Food'].unique())

print("Numerical in 'Diet_Tea_Coffee' variable: ", end=" ")
print(df['Diet_Tea_Coffee'].unique())
# Out:
# Numerical in 'Weight_kg' variable:  [ 66.   56.   89.   55.   45.   42.   60.   84.   70.   54.   73.   65.
#   37.   49.   50.   47.   38.   75.   52.   40.   86.   68.  115.   64.
#   53.   43.   57.   51.   69.   59.   63.   47.5  39.   36.   79.   44.
#   54.5  62.   67.   58.   41.   80.   78.   38.5  87.   46.   61.   48.
#   72.   71.   56.6  83.   90. ]
# Numerical in 'Height_ft' variable:  [157.48 165.1  167.64 160.02 152.4  172.72 170.18 154.94 162.56 175.26
#  144.78 147.32 129.54 149.86 182.88 124.46]
# Numerical in 'Diet_Sweets' variable:  [3 0 1 5 2 7 4 6]
# Numerical in 'Diet_Fried_Food' variable:  [3 1 5 2 7 4 0 6]
# Numerical in 'Diet_Tea_Coffee' variable:  [7 0 5 1 2 6 4 3]

# %%
# %matplotlib inline
fig, axs = plt.subplots(1, 2, figsize=(15,7))
plt.subplot(121)
sns.histplot(data = df, x = 'Diet_Fried_Food', bins=30, kde=True, color='g')
plt.subplot(122)
sns.histplot(data = df, x = 'Diet_Tea_Coffee', kde=True, hue='Age')
# Out:
# <Axes: xlabel='Diet_Tea_Coffee', ylabel='Count'>

# %%
fig, axs = plt.subplots(1,2, figsize=(15,7))
plt.subplot(121)
sns.histplot(data = df, x = 'Sleep_Hours', bins=30, kde=True, hue='Age', color='g')
plt.subplot(122)
sns.histplot(data=df, x = 'Vegetarian', kde=True, hue='Marital_Status')
# Out:
# <Axes: xlabel='Vegetarian', ylabel='Count'>

# %% [markdown]
# ## Graph between married and unmarried status

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data = df )
# Out:
# <Axes: ylabel='Count'>

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data = df, x = 'PCOS', kde=True, hue= 'Age')
plt.subplot(142)
sns.histplot(data=df[df.Marital_Status=='Unmarried'], x = 'Age',kde=True, hue='Vegetarian')
plt.subplot(143)
sns.histplot(data=df[df.Marital_Status=='Married'], x = 'Age', kde=True, hue='Vegetarian')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
